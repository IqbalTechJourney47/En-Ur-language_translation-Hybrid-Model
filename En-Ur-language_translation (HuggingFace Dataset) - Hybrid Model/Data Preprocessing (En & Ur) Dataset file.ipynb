# %% [markdown]
# # 2. Getting Started with spaCy and its Linguistic Annotations

# %% [markdown]
# # English (en) dataset

# %% [markdown]
# ## 2.1. Importing spaCy and Loading Data

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# Thesis tab-delimited dataset file

with open ('eng_-urdu.en', 'r') as f:
    tt_dfile_en = f.read()

# %%
print(tt_dfile_en)
# Out:
# This then is the message which we have heard of him , and declare unto you , that God is light , and in him is no darkness at all .
# And saying , Alas , alas , that great city , that was clothed in fine linen , and purple , and scarlet , and decked with gold , and precious stones , and pearls !
# For in one hour so great riches is come to nought . And every shipmaster , and all the company in ships , and sailors , and as many as trade by sea , stood afar off .
# And cried when they saw the smoke of her burning , saying , What city is like unto this great city !
# And the voice of harpers , and musicians , and of pipers , and trumpeters , shall be heard no more at all in thee ; and no craftsman , of whatsoever craft he be , shall be found any more in thee ; and the sound of a millstone shall be heard no more at all in thee .
# And these things write we unto you , that your joy may be full .
# ...

# %% [markdown]
# ## 2.2. Creating a Doc Container

# %%
doc_en = nlp(tt_dfile_en)

# %%
print(doc_en)
# Out:
# This then is the message which we have heard of him , and declare unto you , that God is light , and in him is no darkness at all .
# And saying , Alas , alas , that great city , that was clothed in fine linen , and purple , and scarlet , and decked with gold , and precious stones , and pearls !
# For in one hour so great riches is come to nought . And every shipmaster , and all the company in ships , and sailors , and as many as trade by sea , stood afar off .
# And cried when they saw the smoke of her burning , saying , What city is like unto this great city !
# And the voice of harpers , and musicians , and of pipers , and trumpeters , shall be heard no more at all in thee ; and no craftsman , of whatsoever craft he be , shall be found any more in thee ; and the sound of a millstone shall be heard no more at all in thee .
# And these things write we unto you , that your joy may be full .
# ...

# %%
print(len(tt_dfile_en))
print(len(doc_en))
# Out:
# 11855
# 2328

# %%
#import nltk
#nltk.download("punkt")

# %%
from nltk.tokenize import word_tokenize

# %%
# Tokenize the text using NLTK
tokens_en = word_tokenize(tt_dfile_en)

# %% [markdown]
# ## Special Characters Handling

# %%
import string
import re
import nltk

# prepare regex for char filtering
re_punc = re.compile('[%s]' % re.escape(string.punctuation))
print(re_punc)
# Out:
# re.compile('[!"\\#\\$%\\&\'\\(\\)\\*\\+,\\-\\./:;<=>\\?@\\[\\\\\\]\\^_`\\{\\|\\}\\~]')

# %%
import re
import string

# Your existing regular expression for character filtering
re_punc = re.compile('[%s]' % re.escape(string.punctuation))

# Define a string containing additional punctuation characters to be filtered
additional_punctuation = "!@#$%^&*()_+=-[]{};:'\"<>,.?/~`|\\©→"

# Update the regular expression pattern to include additional punctuation
re_punc = re.compile('[%s]' % re.escape(string.punctuation + additional_punctuation))

# Test the updated regular expression pattern
text = "This is an example sentence with additional punctuation: !@#$%^&*©→"
filtered_text = re_punc.sub('', text)
print(filtered_text)
# Out:
# This is an example sentence with additional punctuation

# %%
# remove punctuation from each word
stripped_en_tt_dfile = [re_punc.sub('', w) for w in tokens_en]
print(stripped_en_tt_dfile)
# Out:
# ['This', 'then', 'is', 'the', 'message', 'which', 'we', 'have', 'heard', 'of', 'him', '', 'and', 'declare', 'unto', 'you', '', 'that', 'God', 'is', 'light', '', 'and', 'in', 'him', 'is', 'no', 'darkness', 'at', 'all', '', 'And', 'saying', '', 'Alas', '', 'alas', '', 'that', 'great', 'city', '', 'that', 'was', 'clothed', 'in', 'fine', 'linen', '', 'and', 'purple', '', 'and', 'scarlet', '', 'and', 'decked', 'with', 'gold', '', 'and', 'precious', 'stones', '', 'and', 'pearls', '', 'For', 'in', 'one', 'hour', 'so', 'great', 'riches', 'is', 'come', 'to', 'nought', '', 'And', 'every', 'shipmaster', '', 'and', 'all', 'the', 'company', 'in', 'ships', '', 'and', 'sailors', '', 'and', 'as', 'many', 'as', 'trade', 'by', 'sea', '', 'stood', 'afar', 'off', '', 'And', 'cried', 'when', 'they', 'saw', 'the', 'smoke', 'of', 'her', 'burning', '', 'saying', '', 'What', 'city', 'is', 'like', 'unto', 'this', 'great', 'city', '', 'And', 'the', 'voice', 'of', 'harpers', '', 'and', 'musicians', '', 'and', '
# ...

# %%
# remove remaining tokens that are not alphabetic
words_en_tt_dfile = [word for word in stripped_en_tt_dfile if word.isalpha()]
print(words_en_tt_dfile)
# Out:
# ['This', 'then', 'is', 'the', 'message', 'which', 'we', 'have', 'heard', 'of', 'him', 'and', 'declare', 'unto', 'you', 'that', 'God', 'is', 'light', 'and', 'in', 'him', 'is', 'no', 'darkness', 'at', 'all', 'And', 'saying', 'Alas', 'alas', 'that', 'great', 'city', 'that', 'was', 'clothed', 'in', 'fine', 'linen', 'and', 'purple', 'and', 'scarlet', 'and', 'decked', 'with', 'gold', 'and', 'precious', 'stones', 'and', 'pearls', 'For', 'in', 'one', 'hour', 'so', 'great', 'riches', 'is', 'come', 'to', 'nought', 'And', 'every', 'shipmaster', 'and', 'all', 'the', 'company', 'in', 'ships', 'and', 'sailors', 'and', 'as', 'many', 'as', 'trade', 'by', 'sea', 'stood', 'afar', 'off', 'And', 'cried', 'when', 'they', 'saw', 'the', 'smoke', 'of', 'her', 'burning', 'saying', 'What', 'city', 'is', 'like', 'unto', 'this', 'great', 'city', 'And', 'the', 'voice', 'of', 'harpers', 'and', 'musicians', 'and', 'of', 'pipers', 'and', 'trumpeters', 'shall', 'be', 'heard', 'no', 'more', 'at', 'all', 'in', 'thee',
# ...

# %%
# Assuming you have the 'words_tt_dfile' list containing alphabetic words

# Specify the file path where you want to save the tab-delimited file
file_path = 'words_en_tt_dfile.tsv'

# Open the file in write mode
# , encoding='utf-8'
with open(file_path, 'w') as file:
    # Write the header if needed (optional)
    # file.write('Word\n')

    # Write each word followed by a tab character to create a tab-delimited file
    for word in words_en_tt_dfile:
        file.write(word + '\t')

# Print a message indicating the successful save
print(f'Tab-delimited file saved to {file_path}')
# Out:
# Tab-delimited file saved to words_en_tt_dfile.tsv

# %% [markdown]
# # Urdu (ur) dataset

# %% [markdown]
# ## 2.1. Importing stanza and Loading Data

# %%
import stanza

stanza.download('urdu')
# Out:
# ...
# 2023-11-27 12:46:49 INFO: "urdu" is an alias for "ur"
# 2023-11-27 12:46:49 INFO: Downloading default packages for language: ur (Urdu) ...
# 2023-11-27 12:46:49 INFO: File exists: C:\Users\Muhammad Iqbal\stanza_resources\ur\default.zip
# 2023-11-27 12:46:50 INFO: Finished downloading models and saved to C:\Users\Muhammad Iqbal\stanza_resources.

# %%
nlp = stanza.Pipeline('ur')
# Out:
# 2023-11-27 12:46:50 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# 2023-11-27 12:46:51 INFO: Loading these models for language: ur (Urdu):
# ...
# | Processor | Package       |
# -----------------------------
# | tokenize  | udtb          |
# | pos       | udtb_nocharlm |
# | lemma     | udtb_nocharlm |
# | depparse  | udtb_nocharlm |
# ...
#
# 2023-11-27 12:46:51 INFO: Using device: cpu
# 2023-11-27 12:46:51 INFO: Loading: tokenize
# 2023-11-27 12:46:51 INFO: Loading: pos
# 2023-11-27 12:46:51 INFO: Loading: lemma
# 2023-11-27 12:46:51 INFO: Loading: depparse
# 2023-11-27 12:46:51 INFO: Done loading processors!

# %%
# Thesis tab delimited file

with open ('data/my.en-ur1-clean.ur', 'r', encoding='utf-8') as f:
    tt_dfile_ur = f.read()

# %%
print(tt_dfile_ur)
# Out:
# ُس سے سُنکر جو پَیغام ہم تُمہیں دیتے ہیں وہ یہ ہے کہ خُدا نُور ہے اور اُس میں ذرا بھی تارِیکی نہیں ۔
# اور کہیں گے افسوس ! افسوس ! وہ بڑا شہر جو مہِین کتانی اور ارغوانی اور قِرمزی کپڑے پہنے ہُوئے اور سونے اور جواہِر اور موتِیوں سے آراستہ تھا !
# گھڑی ہی بھر میں اُس کی اِتنی بڑی دَولت برباد ہو گئی اور سب ناخُدا اور جہاز کے سب مُسافِر اور ملاح اور اَور جِتنے سمُندر کا کام کرتے ہیں ۔
# جب اُس کے جلنے کا دھُواں دیکھیں گے تو دُور کھڑے ہُوئے چِلائیں گے اور کہیں گے کَون سا شہر اِس بڑے شہر کی مانِند ہے ؟
# اور بربط نوازوں اور مُطِربوں اور بانسلی بجانے والوں اور نرسِنگا پھُونکنے والوں کی آواز پھِر کبھی تُجھ میں نہ سُنائی دے گی اور کِسی پیشہ کا کاریگر تُجھ میں پھِر کبھی نہ پایا جائے گا اور چکّی کی آواز تُجھ میں پھِر کبھی نہ سُنائی دے گی ۔
# اور یہ باتیں ہم اس لئے لکھتے ہیں کہ ہماری خوشی پوری ہو جائے ۔
# کینیڈا اب تک 50 امن مشنوں میں حصہ لے چکا ہے جس میں 1989 سے اب تک کے تمام بحالی امن کے مشن شامل ہیں۔
# شیخ شہاب الدین سہروردی کی عوارف المعارف
# ...

# %% [markdown]
# ## Creating a Doc Container

# %%
doc_ur = nlp(tt_dfile_ur)

# %%
print(doc_ur)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "ُس",
#       "lemma": "ُس",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 8,
#       "deprel": "obl",
#       "start_char": 0,
#       "end_char": 2
#     },
#     {
#       "id": 2,
#       "text": "سے",
#       "lemma": "سے",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 1,
#       "deprel": "case",
#       "start_char": 3,
#       "end_char": 5
#     },
#     {
#       "id": 3,
#       "text": "سُنکر",
#       "lemma": "سُنکر",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 11,
#       "deprel": "nsubj",
#       "start_char": 6,
#       "end_char": 11
#     },
#     {
#       "id": 4,
#       "text": "جو",
#       "lemma": "جو",
#       "upos": "PRON",
#       "xpos": "PRP",
# ...

# %%
from nltk.tokenize import word_tokenize

# Tokenize the text using NLTK
tokens_ur = word_tokenize(tt_dfile_ur)

# %% [markdown]
# ## Special Characters Handling

# %%
import string
import re
import nltk
nltk.download('punkt')

# prepare regex for char filtering
re_punc = re.compile('[%s]' % re.escape(string.punctuation))
print(re_punc)
# Out:
# re.compile('[!"\\#\\$%\\&\'\\(\\)\\*\\+,\\-\\./:;<=>\\?@\\[\\\\\\]\\^_`\\{\\|\\}\\~]')
# [nltk_data] Downloading package punkt to C:\Users\Muhammad
# [nltk_data]     Iqbal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import re
import string

# Your existing regular expression for character filtering
re_punc = re.compile('[%s]' % re.escape(string.punctuation))

# Define a string containing additional punctuation characters to be filtered
additional_punctuation = "!@#$%^&*()_+=-[]{};:'\"<>,.?/~`|\\©→"

# Update the regular expression pattern to include additional punctuation
re_punc = re.compile('[%s]' % re.escape(string.punctuation + additional_punctuation))

# Test the updated regular expression pattern
text = "کینیڈا باشندہ انگریزی فرانسیسی کم از کم زبان جاننا لازمی: !@#$%^&*"
filtered_text = re_punc.sub('', text)
print(filtered_text)
# Out:
# کینیڈا باشندہ انگریزی فرانسیسی کم از کم زبان جاننا لازمی

# %%
# remove punctuation from each word
stripped_ur_tt_dfile = [re_punc.sub('', w) for w in tokens_ur]
print(stripped_ur_tt_dfile)
# Out:
# ['ُس', 'سے', 'سُنکر', 'جو', 'پَیغام', 'ہم', 'تُمہیں', 'دیتے', 'ہیں', 'وہ', 'یہ', 'ہے', 'کہ', 'خُدا', 'نُور', 'ہے', 'اور', 'اُس', 'میں', 'ذرا', 'بھی', 'تارِیکی', 'نہیں', '۔', 'اور', 'کہیں', 'گے', 'افسوس', '', 'افسوس', '', 'وہ', 'بڑا', 'شہر', 'جو', 'مہِین', 'کتانی', 'اور', 'ارغوانی', 'اور', 'قِرمزی', 'کپڑے', 'پہنے', 'ہُوئے', 'اور', 'سونے', 'اور', 'جواہِر', 'اور', 'موتِیوں', 'سے', 'آراستہ', 'تھا', '', 'گھڑی', 'ہی', 'بھر', 'میں', 'اُس', 'کی', 'اِتنی', 'بڑی', 'دَولت', 'برباد', 'ہو', 'گئی', 'اور', 'سب', 'ناخُدا', 'اور', 'جہاز', 'کے', 'سب', 'مُسافِر', 'اور', 'ملاح', 'اور', 'اَور', 'جِتنے', 'سمُندر', 'کا', 'کام', 'کرتے', 'ہیں', '۔', 'جب', 'اُس', 'کے', 'جلنے', 'کا', 'دھُواں', 'دیکھیں', 'گے', 'تو', 'دُور', 'کھڑے', 'ہُوئے', 'چِلائیں', 'گے', 'اور', 'کہیں', 'گے', 'کَون', 'سا', 'شہر', 'اِس', 'بڑے', 'شہر', 'کی', 'مانِند', 'ہے', '؟', 'اور', 'بربط', 'نوازوں', 'اور', 'مُطِربوں', 'اور', 'بانسلی', 'بجانے', 'والوں', 'اور', 'نرسِنگا', 'پھُونکنے', 'والوں', 'کی', 'آواز', 'پھِر', 'کبھی', 'تُجھ', 'میں', 'نہ',
# ...

# %%
# remove remaining tokens that are not alphabetic
words_ur_tt_dfile = [word for word in stripped_ur_tt_dfile if word.isalpha()]
print(words_ur_tt_dfile)
# Out:
# ['سے', 'جو', 'ہم', 'دیتے', 'ہیں', 'وہ', 'یہ', 'ہے', 'کہ', 'ہے', 'اور', 'میں', 'ذرا', 'بھی', 'نہیں', 'اور', 'کہیں', 'گے', 'افسوس', 'افسوس', 'وہ', 'بڑا', 'شہر', 'جو', 'کتانی', 'اور', 'ارغوانی', 'اور', 'کپڑے', 'پہنے', 'اور', 'سونے', 'اور', 'اور', 'سے', 'آراستہ', 'تھا', 'گھڑی', 'ہی', 'بھر', 'میں', 'کی', 'بڑی', 'برباد', 'ہو', 'گئی', 'اور', 'سب', 'اور', 'جہاز', 'کے', 'سب', 'اور', 'ملاح', 'اور', 'کا', 'کام', 'کرتے', 'ہیں', 'جب', 'کے', 'جلنے', 'کا', 'دیکھیں', 'گے', 'تو', 'کھڑے', 'گے', 'اور', 'کہیں', 'گے', 'سا', 'شہر', 'بڑے', 'شہر', 'کی', 'ہے', 'اور', 'بربط', 'نوازوں', 'اور', 'اور', 'بانسلی', 'بجانے', 'والوں', 'اور', 'والوں', 'کی', 'آواز', 'کبھی', 'میں', 'نہ', 'دے', 'گی', 'اور', 'پیشہ', 'کا', 'کاریگر', 'میں', 'کبھی', 'نہ', 'پایا', 'جائے', 'گا', 'اور', 'کی', 'آواز', 'میں', 'کبھی', 'نہ', 'دے', 'گی', 'اور', 'یہ', 'باتیں', 'ہم', 'اس', 'لئے', 'لکھتے', 'ہیں', 'کہ', 'ہماری', 'خوشی', 'پوری', 'ہو', 'جائے', 'کینیڈا', 'اب', 'تک', 'امن', 'مشنوں', 'میں', 'حصہ', 'لے', 'چکا', 'ہے', 'جس', 'میں', 'سے', 'اب', 
# ...

# %%
# Assuming you have the 'words_tt_dfile' list containing alphabetic words

# Specify the file path where you want to save the tab-delimited file
file_path = 'words_ur_tt_dfile.tsv'

# Open the file in write mode with UTF-8 encoding
with open(file_path, 'w', encoding='utf-8') as file:
    # Write the header if needed (optional)
    # file.write('Word\n')

    # Write each word followed by a tab character to create a tab-delimited file
    for word in words_ur_tt_dfile:
        file.write(word + '\t')

# Print a message indicating the successful save
print(f'Tab-delimited file saved to {file_path}')
# Out:
# Tab-delimited file saved to words_ur_tt_dfile.tsv
