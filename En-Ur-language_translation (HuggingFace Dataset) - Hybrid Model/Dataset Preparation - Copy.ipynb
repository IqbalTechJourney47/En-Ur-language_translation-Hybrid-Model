# %% [markdown]
# Natural Language Processing with spaCy & Python - Course for Beginners
#
# https://www.youtube.com/watch?v=dIUTsFT2MeQ
#
# https://spacy.pythonhumanities.com/intro.html

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm

# %% [markdown]
# # 2. Getting Started with spaCy and its Linguistic Annotations

# %% [markdown]
# ## 2.1. Importing spaCy and Loading Data

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
#with open ('data/en.maududi.txt', 'r', encoding='utf-8') as f:
#    text = f.read()

# %%
#print(text)

# %%
# Thesis tab delimited file

#with open ('data/dev.ur-en.en.0', 'r', encoding='utf-8') as f:
#    tt_dfile = f.read()

# %%
#print(tt_dfile)

# %%
# Thesis tab delimited file

#with open ('data/my.en-ur1-clean.en', 'r', encoding='utf-8') as f:
#    tt_dfile = f.read()

# %%
#print(tt_dfile)

# %%
# Thesis tab delimited file

with open ('data/my.en-ur1-clean-editing.en', 'r', encoding='utf-8') as f:
    tt_dfile = f.read()

# %%
#print(tt_dfile)

# %% [markdown]
# ## 2.2. Creating a Doc Container

# %%
doc = nlp(tt_dfile)

# %%
# print(doc)

# %%
print(len(tt_dfile))
print(len(doc))
# Out:
# 481502
# 109293

# %% [markdown]
# ## 2.6. Named Entity Recognition (NER)

# %%
# Thesis tab delimited file

with open ('data/my.en-ur1-clean-editing.en', 'r', encoding='utf-8') as f:
    tt_dfile = f.read()

# %%
#print(tt_dfile)

# %%
from spacy import displacy
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Royal Horse Army
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which is also the official national police is the source of international recognition<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hockey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a national hobby, at this time
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...
